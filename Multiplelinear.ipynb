# %% [markdown]
# <a href="https://colab.research.google.com/github/ruchasangaonkar2006/SY/blob/main/Multiplelinear.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

from sklearn.model_selection import train_test_split
from sklearn.linear_model import LinearRegression
from sklearn.metrics import mean_squared_error, r2_score

# %% [markdown]
# create dataset

# %%
data = {"size":[700,900,1000,1000,1200,1500,1500,1700,1800,1800,2000,2200],
        "bhk":[1,1,1,2,2,2,3,3,3,4,4,4],
        "price":[1800000,2000000,2200000,2500000,2750000,3200000,3500000,4000000,4175000,4800000,5100000,5200000]}

# %%
df=pd.DataFrame(data)
print(df)
# Out:
#     size  bhk    price
# 0    700    1  1800000
# 1    900    1  2000000
# 2   1000    1  2200000
# 3   1000    2  2500000
# 4   1200    2  2750000
# 5   1500    2  3200000
# 6   1500    3  3500000
# 7   1700    3  4000000
# 8   1800    3  4175000
# 9   1800    4  4800000
# 10  2000    4  5100000
# 11  2200    4  5200000

# %%
df.corr()
# Out:
#            size       bhk     price
# size   1.000000  0.937254  0.981432
# bhk    0.937254  1.000000  0.976739
# price  0.981432  0.976739  1.000000

# %% [markdown]
# visulize using Seaborn

# %%
sns.pairplot(df)

# %% [markdown]
# Dependent & Independent features

# %%
X=df[["size","bhk"]]
y=df[["price"]]
X_train,X_test,y_train,y_test=train_test_split(X,y,test_size=0.15,random_state=42)
X_test.shape
X_train.shape
y_test.shape
y_train.shape
# Out:
# (10, 1)

# %% [markdown]
# Model Training

# %%
model = LinearRegression()
model.fit(X_train, y_train)
# Out:
# LinearRegression()

# %% [markdown]
# Scatter plot

# %%
plt.scatter(df["size"],df["bhk"])
print("intercept",model.intercept_)
print("coefficient",model.coef_)
# Out:
# intercept [206255.56544969]
# coefficient [[  1652.27070347 316217.72039181]]

# %% [markdown]
# Make predictions

# %%
y_pred = model.predict(X_test)
print("predicted=",y_pred)
print("actual=",y_test.values)
# Out:
# predicted= [[4775667.8539626 ]
#  [4445213.71326803]]
# actual= [[5100000]
#  [4800000]]

# %% [markdown]
# Evaluate Model

# %%
mse=mean_squared_error(y_test,y_pred)
print("Mean Squared Error:",mse)
r2=r2_score(y_test,y_pred)
print("R-squared:",r2)
# Out:
# Mean Squared Error: 115532325103.14224
# R-squared: -4.1347700045841

# %% [markdown]
# Predict the price of new house

# %%
a=[[1800,2]]
predicted_price=model.predict(a)
print("predicted_price is :",predicted_price)

b=int(input("Enter the size of house:"))
c=int(input("Enter the number of bhk"))
p_price=model.predict([[b,c]])
print("predicted_price is :",p_price)
# Out:
# /usr/local/lib/python3.12/dist-packages/sklearn/utils/validation.py:2739: UserWarning: X does not have valid feature names, but LinearRegression was fitted with feature names
#   warnings.warn(
# predicted_price is : [[3812778.27248442]]
# Enter the size of house:1800
# Enter the number of bhk3
# predicted_price is : [[4128995.99287622]]
# /usr/local/lib/python3.12/dist-packages/sklearn/utils/validation.py:2739: UserWarning: X does not have valid feature names, but LinearRegression was fitted with feature names
#   warnings.warn(
